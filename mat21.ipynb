# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
file_path = r"C:\Users\HP\Downloads\\Used_Bikes.csv"
df = pd.read_csv(file_path)
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %% [markdown]
# Using this data for futhur ploting

# %% [markdown]
# Scatter Plot:A scatter plot is a graphical representation of data where each point on the graph represents a pair of values. It is commonly used to visualize the relationship between two variables. Scatter plots are useful for identifying patterns, trends, and outliers in the data.
#
# Here are some key points about scatter plots:
#
# 1.
# Each point on the scatter plot represents a pair of values (x, y).
# 2.
# The position of each point on the graph is determined by the values of x and y.
# 3.
# The scatter plot can be used to identify patterns, trends, and outliers in the data.
# 4.
# The appearance of the scatter plot can be customized by changing colors, marker styles, and other visual properties.
# 5.
# Scatter plots can be used to compare the relationship between multiple variables or to visualize the distribution of data.

# %%
ls1=[25,35,68,24,61]
ls2=[96,45,12,36,45]
plt.scatter(x=ls1,y=ls2,marker="*")
plt.ylabel('List -2')
plt.xlabel("List-1")

plt.title("Scatter plot")
plt.show()

# %% [markdown]
# Here ,we are customizing with the marker by changing the "*" by "o"

# %% [markdown]
# ALso s= size parameter

# %%
ls1=[25,35,68,24,61]
ls2=[96,45,12,36,45]
# plt.scatter(x=ls1,y=ls2,marker="*",s=500)
# plt.scatter(x=ls1,y=ls2,marker="D",s=500)
plt.scatter(x=ls1,y=ls2,marker="o",s=500,color="pink")
# plt.scatter(x=ls1,y=ls2,marker="*",s=ls2*3)
plt.ylabel('List -2')
plt.xlabel("List-1")

plt.title("Scatter plot")
plt.show()

# %% [markdown]
# Here ,we are customizing with the marker to changing the "*"

# %%
ls1=[25,35,68,24,61]
ls2=[96,45,12,36,45]
# s------>size parameter
plt.scatter(x=ls1,y=ls2,marker="*",s=500,color="black")
# plt.scatter(x=ls1,y=ls2,marker="D",s=500)
# plt.scatter(x=ls1,y=ls2,marker="o",s=500,color="pink")
# plt.scatter(x=ls1,y=ls2,marker="*",s=ls2*3)
plt.ylabel("list -2")
plt.xlabel("list -1")

plt.title("Scatter plot")
plt.show()

# %% [markdown]
# Here we are deleting the duplicate values

# %% [markdown]
# Using scatter plot we can find the density which area has the maximum and minimun distribution(points).

# %%
df.drop_duplicates(inplace=True)

# %%
df['price']
# Out:
# 0        35000.0
# 1       119900.0
# 2       600000.0
# 3        65000.0
# 4        80000.0
#           ...
# 9362     25000.0
# 9369     35000.0
# 9370    450000.0
# 9371    139000.0
# 9372     80000.0
# Name: price, Length: 7324, dtype: float64

# %%
plt.scatter(x=df['kms_driven'],y=df['price'])
plt.xlabel("kms drivens")
plt.ylabel("price")
plt.show()

# %%
import numpy as np
arr1=np.random.randint(1,200,500)
arr1
# Out:
# array([ 23, 170, 182, 172,  10, 176,  46, 177,  37,  11, 168, 142,  12,
#        147, 163,  16,  32,  40, 143, 198, 190, 176, 105,  43,  51,  92,
#         76,  96, 119, 138, 104, 106, 185, 167,  26,  53, 160,   3, 125,
#        190, 133,  55,  83, 178, 178, 164, 163, 120,  72,  55,  81, 111,
#        138,  80, 186,   6, 179,  81,  90, 132,  34,  67,  47, 186,   5,
#        114,  95, 190, 106,  93, 105, 119,  89, 117,  84,  25,  15, 182,
#         22, 115, 132, 189, 100,  12,  87, 115,  98, 126, 181, 149, 146,
#        192,  43, 147,  84, 114,  86, 128,  49, 183,  76,  96, 143, 174,
#         67, 119, 163,  54,  17,  51,   3, 137,  79,  78, 100,  50, 118,
#        156, 171,  79,  23, 195, 160, 167,  18, 195, 186, 185,  29,  61,
#          3,  38, 156,   4, 176, 109,  22,  52, 147, 129,  88,  30, 152,
#        118, 122,  39,  40,  39, 137,  42,  80, 116, 105, 152,  56, 172,
#        139,  39, 103,  35, 169, 169, 104,  44,   8,  49, 180,  46,  83,
# ...

# %%
arr2=arr1*50

# %%
plt.scatter(arr1,arr2)
plt.xlabel("arr-1")
plt.ylabel("arr-2")
plt.show()
# positive relationship plot
# to check relation btw 2 pints

# %% [markdown]
# Histogram:It tells how our data is distributed.
# A histogram plot is a graphical representation of data where the data is divided into bins and the frequency of each bin is represented by a bar. It is commonly used to visualize the distribution of data and identify patterns, trends, and outliers.
#
# Here are some key points about histogram plots:
#
# 1.Each bar in the histogram represents a bin, which is a range of values.
#
#
# 2.The height of each bar represents the frequency or count of data points that fall within that bin.
#
#
# 3.The width of each bar can be adjusted to represent the size of the bins.
#
#
# 4.Histograms can be used to compare the distribution of data between different groups or categories.
#
#
# 5.Histograms can be customized by changing the color, style, and other visual properties.
#
#
# 6.Histograms can be used to identify patterns, trends, and outliers in the data.

# %% [markdown]
# Here we are generating all the random values from 1 to 100

# %%
age=np.random.randint(1,100,1000)
age
# Out:
# array([17, 67,  2, 34, 27, 28, 60, 97, 78, 59, 88, 86, 80, 49, 25, 41, 91,
#        69, 62, 15, 25, 52, 19, 44, 34, 64, 86, 93, 30, 73, 30, 15,  2, 59,
#        71, 97, 59, 13, 47, 51, 43,  3, 72, 90, 72, 81, 24, 66,  8, 88, 22,
#        26,  3, 83,  9, 77, 59, 30, 88, 15, 40, 54, 27, 65, 69, 49, 86, 50,
#        53, 32, 57, 39, 52,  3, 22, 89, 84, 29, 91, 63, 36, 92, 25, 57, 53,
#        85, 31, 84, 63, 61, 45, 89, 39, 19, 12, 70, 41, 14, 38, 50, 14, 54,
#        51,  3, 38, 47, 70, 19, 40, 37, 71,  1, 77, 84, 74, 21,  5, 38, 30,
#        84, 12, 41,  2, 34, 15, 45, 44, 43, 77, 32, 21, 13, 64, 43, 62, 78,
#        43, 67,  7, 33, 94, 23, 96, 35, 78,  7, 17, 36, 41, 44,  7, 38, 54,
#        55, 71, 83, 83, 96, 63, 78, 86, 99,  2, 85, 61, 87, 36, 35, 16, 97,
#        28, 69, 97, 81, 36, 51, 38, 61, 89, 95, 21, 34, 59, 85, 25, 69, 64,
#        61, 16, 99, 26, 38, 35, 31, 29, 27, 66, 18, 72, 61, 23,  2, 90,  2,
# ...

# %%
more_than_18=np.count_nonzero(age<=18)
more_than_18
# Out:
# 176

# %% [markdown]
# Making the histogram using the range

# %%
bucket=[0,18,30,50,70,90,100,110]
plt.hist(age)
plt.show()

# %%
bucket=[0,18,30,50,70,90,110]
plt.hist(age,bins=bucket,ec="k")
plt.show()

# %% [markdown]
# Here we saw the defaults bins of the histogram

# %%
bucket=[0,18,30,50,70,90,110]
# plt.figure=(8,9)
plt.hist(age,ec="k",color='green')
# default bins
# in historgram bars are called bins and in bar plot it is know as barrs
plt.show()

# %% [markdown]
# Here we are finding the minimum and maximum price

# %%
df['price'].min()
# Out:
# np.float64(4400.0)

# %%
df['price'].max()
# Out:
# np.float64(1900000.0)

# %%
b=[0,50000,70000,10000,15000,17000,20000,25000]
plt.hist(df['price'],bins=b,ec='k')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 2
#       1 b=[0,50000,70000,10000,15000,17000,20000,25000]
# ----> 2 plt.hist(df['price'],bins=b,ec='k')
#       3 plt.show()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\pyplot.py:3440, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    3415 @_copy_docstring_and_deprecators(Axes.hist)
#    3416 def hist(
#    3417     x: ArrayLike | Sequence[ArrayLike],
#    (...)
#    3438     BarContainer | Polygon | list[BarContainer | Polygon],
#    3439 ]:
# -> 3440     return gca().hist(
#    3441         x,
#    3442         bins=bins,
#    3443         range=range,
#    3444         density=density,
#    3445         weights=weights,
#    3446         cumulative=cumulative,
# ...

# %% [markdown]
# Box plot:A box plot, also known as a box-and-whisker plot, is a graphical representation of data using a five-number summary (minimum, first quartile, median, third quartile, and maximum). It is commonly used to visualize the distribution of data and identify outliers.
#
# Here are some key points about box plots:
#
# 1.The box represents the interquartile range (IQR), which is the range between the first quartile (25th percentile) and the third quartile (75th percentile).
#
#
# 2.The vertical lines extending from the box represent the minimum and maximum values, excluding outliers.
#
#
# 3.The median (second quartile) is represented by a horizontal line within the box.
#
#
# 4.Outliers are represented by individual points outside of the whiskers, which extend from the ends of the box.
#
#
# 5.Box plots can be used to compare the distribution of data between different groups or categories.
#
#
# 6.Box plots can be customized by changing the color, style, and other visual properties.

# %%
plt.boxplot(age)
plt.show()

# %%
plt.boxplot(df[df['brand']=="Bajaj"]['price'])
plt.show()
# To deal with it:-
# (1)remove
# (2)normalize
